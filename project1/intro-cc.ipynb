# %% [markdown]
# For this analysis we will look at respective household income extremes in republican vs democratic districts. To do so, we will leverage two data sources that we will need to combine together.
#
# First, we will use the American Community Survey 2021 dataset available from census.gov. The data is available via API from here: https://www.census.gov/data/developers/data-sets/acs-1year.html. This data is commonly referenced when people are looking for demographic breakdowns of the American population. This data refers back to the 116th congressional district.
#
# Second, to get the party affiliation of each congressional district, we will use https://www.house.gov/representatives. Someone has already scraped the house.gov site to turn it into a csv here: http://goodcsv.com/politics/us-house-of-representatives-2020/ for the 116th congressional district.

# %%
# first some initial setup of libraries we will be using
import pandas as pd # this is the main library used in python for manipulating data. 
import json # this is a library to parse json (javascript object notation)
from urllib.request import urlopen # library to read data from a URL
import matplotlib.pyplot as plt # visualization library we will use that integrates with pandas

# %% [markdown]
# First we will read the ACS 2021 dataset and get it into a usable state for our data analysis.

# %%
# We are reading in the data we want from ACS 2021. The API returns json data. Try copy and pasting the link yourself in a browser to see what the raw data looks like.
url="https://api.census.gov/data/2021/acs/acs1?get=NAME,B19001_001E,B19001_002E,B19001_017E&for=congressional%20district:*&in=state:*"

# store the response of URL
response = urlopen(url)

# storing the JSON response from url in data
data_json = json.loads(response.read())
data_json.pop(0) # the first row of data is header information which we don't need, so pop removes that from the dataset.

# Hand populate the columns based on the variable descriptions census.gov documents here:
# https://api.census.gov/data/2021/acs/acs1/variables.html. Note they correspond back to the variable names I included in the URL above.
cols = ['District Name','Total Households','Less than $10k', '$200k+', 'State code', 'district number']

acs_df = pd.DataFrame(data_json, columns = cols)

# time to do some basic cleanup of the data. We will need to extract the district number and state in a regular format so we can later join with the party data.
acs_df[['District', 'State']] = acs_df['District Name'].str.split(',', expand=True)
acs_df['district number'] = pd.to_numeric(acs_df['district number'])

acs_df['State'] = acs_df['State'].str.strip()

# Let's just keep the columns we need
acs_df = acs_df[['Total Households', 'Less than $10k', "$200k+", 'district number', 'State']]

# take a look at the top results in the dataset
acs_df.head()
# Out:
#   Total Households Less than $10k $200k+  district number        State
# 0           289474          14153  19390               10     Michigan
# 1           299804          23793  10899                4  Mississippi
# 2           278057          27728  19574               14     Michigan
# 3           306685          19036  12208                1     Michigan
# 4           285554          26481  12412                3  Mississippi

# %%
# Convert the number columns into number data types so we can math on them
acs_df["Total Households"] = pd.to_numeric(acs_df["Total Households"])
acs_df["Less than $10k"] = pd.to_numeric(acs_df["Less than $10k"])
acs_df['$200k+'] = pd.to_numeric(acs_df['$200k+'])

# Compute some new columns based on the existing columns for later visualization
acs_df['% of households over $200k'] = (100*acs_df['$200k+'])/acs_df['Total Households']
acs_df['% of households less than $10k'] = (100*acs_df['Less than $10k'])/acs_df['Total Households']

# now let's look at the data again
acs_df.head()
# Out:
#    Total Households  Less than $10k  $200k+  district number        State  \
# 0            289474           14153   19390               10     Michigan
# 1            299804           23793   10899                4  Mississippi
# 2            278057           27728   19574               14     Michigan
# 3            306685           19036   12208                1     Michigan
# 4            285554           26481   12412                3  Mississippi
#
#    % of households over $200k  % of households less than $10k
# 0                    6.698356                        4.889213
# 1                    3.635375                        7.936185
# 2                    7.039564                        9.972056
# 3                    3.980632                        6.207020
# 4                    4.346638                        9.273552

# %% [markdown]
# Now let's get our party affiliation data in a state to merge with the ACS data.

# %%
# read from the congressional data and put into a pandas dataframe
party_df = pd.read_csv("http://goodcsv.com/wp-content/uploads/2020/08/us-house-of-representatives-2020.csv", encoding = "ISO-8859-1")

# extract the district number from the data (it was in the format of 5th and we want that to just be 5) using a regular expression.
party_df['district number'] = party_df['District/Position'].str.extract('(\d+)')
party_df['district number'] = party_df['district number'].fillna(0)
party_df['district number'] = pd.to_numeric(party_df['district number'])
party_df['State'] = party_df['State/Territory']
party_df['State'] = party_df['State'].str.strip()
party_df['Party'] = party_df['Party'].str.strip() # remove extraneous whitespace

# Let's just keep the columns we need
party_df = party_df[['State', 'Party', "district number"]]

party_df.head(5)
# Out:
#             State Party  district number
# 0       Louisiana     R                5
# 1  North Carolina     D               12
# 2         Alabama     R                4
# 3      California     D               31
# 4         Georgia     R               12

# %% [markdown]
# Let's pull some statistics on the two datasets quickly before we join them so we can sanity check that the join worked ok.

# %%
party_df['State'].value_counts()
# Out:
# California                  53
# Texas                       36
# New York                    27
# Florida                     27
# Pennsylvania                18
# Illinois                    18
# Ohio                        16
# Michigan                    14
# Georgia                     14
# North Carolina              13
# New Jersey                  12
# Virginia                    11
# Washington                  10
# Indiana                      9
# Arizona                      9
# Tennessee                    9
# Massachusetts                9
# Minnesota                    8
# Missouri                     8
# Maryland                     8
# Wisconsin                    8
# Colorado                     7
# Alabama                      7
# South Carolina               7
# Louisiana                    6
# Kentucky                     6
# Oklahoma                     5
# Oregon                       5
# Connecticut                  5
# Nevada                       4
# Kansas                       4
# Arkansas                     4
# Iowa                         4
# Mississippi                  4
# Utah                         4
# West Virginia                3
# Nebraska                     3
# New Mexico                   3
# New Hampshire                2
# Maine                        2
# Rhode Island                 2
# Idaho                        2
# Hawaii                       2
# Montana                      1
# Puerto Rico                  1
# Wyoming                      1
# South Dakota                 1
# Delaware                     1
# North Dakota                 1
# District of Columbia         1
# Virgin Islands               1
# American Samoa               1
# Northern Mariana Islands     1
# Guam                         1
# Vermont                      1
# Alaska                       1
# Name: State, dtype: int64

# %%
acs_df['State'].value_counts()
# Out:
# California              53
# Texas                   36
# Florida                 27
# New York                27
# Illinois                18
# Pennsylvania            18
# Ohio                    16
# Georgia                 14
# Michigan                14
# North Carolina          13
# New Jersey              12
# Virginia                11
# Washington              10
# Indiana                  9
# Massachusetts            9
# Arizona                  9
# Tennessee                9
# Missouri                 8
# Wisconsin                8
# Minnesota                8
# Maryland                 8
# South Carolina           7
# Alabama                  7
# Colorado                 7
# Kentucky                 6
# Louisiana                6
# Connecticut              5
# Oklahoma                 5
# Oregon                   5
# Iowa                     4
# Kansas                   4
# Arkansas                 4
# Mississippi              4
# Nevada                   4
# Utah                     4
# New Mexico               3
# West Virginia            3
# Nebraska                 3
# Rhode Island             2
# New Hampshire            2
# Hawaii                   2
# Idaho                    2
# Maine                    2
# South Dakota             1
# Wyoming                  1
# Alaska                   1
# Montana                  1
# North Dakota             1
# Vermont                  1
# Delaware                 1
# Puerto Rico              1
# District of Columbia     1
# Name: State, dtype: int64

# %% [markdown]
# So the ACS dataset has stats for DC and Puerto Rico. The party datset has other terratories like the Virgin Islands. The state counts look right though. Let's go ahead and merge.

# %%
# Merge is like a sql natural join. We are joining on the State and District numbers being the same between the two sets.
merged_df = pd.merge(acs_df, party_df, on=["State", "district number"])

# %%
merged_df.describe()
# Out:
#        Total Households  Less than $10k         $200k+  district number  \
# count        435.000000      435.000000     435.000000       435.000000
# mean      292471.643678    17605.977011   28522.944828        10.158621
# std        33670.787672     6047.931263   18902.411362        10.656779
# min       183319.000000     6021.000000    5296.000000         0.000000
# 25%       273747.000000    13416.000000   14916.000000         3.000000
# 50%       292311.000000    16617.000000   22543.000000         6.000000
# 75%       311849.500000    21013.500000   37009.500000        13.000000
# max       448949.000000    44929.000000  111988.000000        53.000000
#
#        % of households over $200k  % of households less than $10k
# count                  435.000000                      435.000000
# mean                     9.721602                        6.050237
# std                      6.417955                        2.106075
# min                      2.025905                        2.208934
# 25%                      5.184740                        4.653305
# 50%                      7.618205                        5.679285
# 75%                     12.689262                        7.036059
# max                     41.846370                       16.858153

# %% [markdown]
# There are 435 total rows, which matches up with the number of congress members in the 116th congress. Looks pretty good. Let's do a final check by looking at party counts.

# %%
# let's take a look at the party breakdown and sanity check that it looks right
merged_df['Party'].value_counts()
# Out:
# D    233
# R    201
# L      1
# Name: Party, dtype: int64

# %% [markdown]
# Let's do our visualization now. We will do a scatter plot of congressional districts and look at the % of households earning over \$200k on one axis and % of households less than $10k on the other axis. We will color the plot based upon the party affiliation of the districts congress member as of the 116th congress.

# %%
R = merged_df[merged_df['Party'].str.contains('R')]
D = merged_df[merged_df['Party'].str.contains('D')]
L = merged_df[merged_df['Party'].str.contains('L')]

fig, ax = plt.subplots(figsize=(15, 12))
R.plot.scatter(x='% of households over $200k', y='% of households less than $10k', c='red',label='Republican', ax=ax)
D.plot.scatter(x='% of households over $200k', y='% of households less than $10k',c='blue',label='Democrat', ax=ax)
L.plot.scatter(x='% of households over $200k', y='% of households less than $10k',c='gold',label='Libertarian', ax=ax)

#for i, txt in enumerate(df['State']):
#   ax.annotate(txt, (df['% of households over $200k'].iat[i], df['% of households less than $10k'].iat[i]))

plt.legend()
plt.show()

# %% [markdown]
# What conclusions do you draw from this data? In what ways could this be misleading? Is there a better visualization that you would use here? What would be your followup analysis?

# %%
merged_df.to_csv("congressional_district_with_parties.csv")

# %% [markdown]
# # Our stuff below

# %%
#read census data
census_df = pd.read_csv("congressional_district_with_parties.csv")
census_df
# Out:
#      Unnamed: 0  Total Households  Less than $10k  $200k+  district number  \
# 0             0            289474           14153   19390               10
# 1             1            299804           23793   10899                4
# 2             2            278057           27728   19574               14
# 3             3            306685           19036   12208                1
# 4             4            285554           26481   12412                3
# ..          ...               ...             ...     ...              ...
# 430         430            297714           15159   18947                6
# 431         431            320905           19373   14584                7
# 432         432            282817           24427    8871                5
# 433         433            287908           17508   15476                6
# 434         434            291660           15750   31091                8
#
#            State  % of households over $200k  % of households less than $10k  \
# 0       Michigan                    6.698356                        4.889213
# 1    Mississippi                    3.635375                        7.936185
# 2       Michigan                    7.039564                        9.972056
# 3       Michigan                    3.980632                        6.207020
# 4    Mississippi                    4.346638                        9.273552
# ..           ...                         ...                             ...
# 430     Missouri                    6.364162                        5.091800
# 431     Missouri                    4.544647                        6.036989
# 432     Michigan                    3.136657                        8.637034
# 433     Michigan                    5.375328                        6.081109
# 434     Michigan                   10.660015                        5.400123
#
#     Party
# 0       R
# 1       R
# 2       D
# 3       R
# 4       R
# ..    ...
# 430     R
# 431     R
# 432     D
# 433     R
# 434     D
#
# [435 rows x 9 columns]

# %%
#import our marriage dataset
marriage = pd.read_excel("/Users/conniechou/Library/CloudStorage/OneDrive-Personal/Connie/Homework/GSB 521 Pierce /Cloud-Computing-Projects/project1/marriage-rates.xlsx")

#clean marriage data by dropping NA values
marriage = marriage.dropna()
marriage.head()
# Out:
#         State      2021      2020      2019      2018      2017      2016  \
# 1     Alabama  7.577566  7.168500  6.697687  6.760408  7.047340  7.147821
# 2      Alaska  6.315232  5.696443  6.512245  6.683952  6.914078  7.103441
# 3     Arizona  5.422112  4.895841  5.302995  5.534434  5.834867  5.930541
# 4    Arkansas  8.216753  7.776878  8.377284  8.863156  9.456845  9.860962
# 5  California  5.184868  3.183391  5.723191  6.035132  6.278250  6.463590
#
#         2015       2014      2013  ...  2006  2005  2004  2003  2002  2001  \
# 1   7.351544   7.806776  7.817785  ...   9.2   9.2   9.4   9.6   9.9   9.4
# 2   7.407588   7.508836  7.293928  ...   8.2   8.2   8.5   8.1   8.3   8.1
# 3   5.922469   5.780449  5.401091  ...   6.5   6.6   6.7   6.5   6.7   7.6
# 4  10.040279  10.112026  9.751052  ...  12.4  12.9  13.4  13.4  14.3  14.3
# 5   6.184957   6.441492  6.460467  ...   6.3   6.4   6.4   6.1   6.2   6.5
#
#    2000  1999  1995  1990
# 1  10.1  10.8   9.8  10.6
# 2   8.9   8.6   9.0  10.2
# 3   7.5   8.2   8.8  10.0
# 4  15.4  14.8  14.4  15.3
# 5   5.8   6.4   6.3   7.9
#
# [5 rows x 26 columns]

# %%
#only keep 2021 column and drop district of columbia
marriage_2021 = marriage[["State", 2021]]
marriage_2021 = marriage_2021.drop(marriage[marriage["State"] == "District of Columbia"].index)
marriage_2021.head()
# Out:
#         State      2021
# 1     Alabama  7.577566
# 2      Alaska  6.315232
# 3     Arizona  5.422112
# 4    Arkansas  8.216753
# 5  California  5.184868

# %%
#merge the two datasets together
my_merge = pd.merge(census_df, marriage_2021, on=["State"])
my_merge = my_merge.rename(columns= {2021: "Marriage Rate"})
my_merge
# Out:
#      Unnamed: 0  Total Households  Less than $10k  $200k+  district number  \
# 0             0            289474           14153   19390               10
# 1             2            278057           27728   19574               14
# 2             3            306685           19036   12208                1
# 3           219            289969           14688   21742                3
# 4           220            283353           16714   12068                4
# ..          ...               ...             ...     ...              ...
# 430         252            322511           18213   19407                0
# 431         311            270163           10992   23553                0
# 432         343            248904           16701   11791                2
# 433         345            227342           26328    6644                3
# 434         346            245955           17904   13007                1
#
#              State  % of households over $200k  \
# 0         Michigan                    6.698356
# 1         Michigan                    7.039564
# 2         Michigan                    3.980632
# 3         Michigan                    7.498043
# 4         Michigan                    4.258998
# ..             ...                         ...
# 430   North Dakota                    6.017469
# 431        Vermont                    8.718070
# 432  West Virginia                    4.737168
# 433  West Virginia                    2.922469
# 434  West Virginia                    5.288366
#
#      % of households less than $10k Party  Marriage Rate
# 0                          4.889213     R       5.161972
# 1                          9.972056     D       5.161972
# 2                          6.207020     R       5.161972
# 3                          5.065369     L       5.161972
# 4                          5.898649     R       5.161972
# ..                              ...   ...            ...
# 430                        5.647249     R       5.162927
# 431                        4.068655     D       7.379525
# 432                        6.709816     R       6.041081
# 433                       11.580790     R       6.041081
# 434                        7.279380     R       6.041081
#
# [435 rows x 10 columns]

# %%
from plotnine import *

# %%
#create a group by for each state and their marriage rates
marr_rate = my_merge.groupby(by="State").agg({"Marriage Rate": "mean"}).reset_index()
marr_rate.head()
# Out:
#         State  Marriage Rate
# 0     Alabama       7.577566
# 1      Alaska       6.315232
# 2     Arizona       5.422112
# 3    Arkansas       8.216753
# 4  California       5.184868

# %%
# group by of percent of households less than $10k
poor = my_merge[['State', "% of households less than $10k"]].groupby("State").mean().reset_index()
poor.head()
# Out:
#         State  % of households less than $10k
# 0     Alabama                        7.802695
# 1      Alaska                        5.390493
# 2     Arizona                        5.760895
# 3    Arkansas                        7.666248
# 4  California                        5.342869

# %%
# group by percent of households more than $200k
rich = my_merge[['State', "% of households over $200k"]].groupby("State").mean().reset_index()
rich.head()
# Out:
#         State  % of households over $200k
# 0     Alabama                    5.100286
# 1      Alaska                   10.209686
# 2     Arizona                    7.863975
# 3    Arkansas                    4.599023
# 4  California                   14.922772

# %%
#merge all 3 together
marr_st_income = marr_rate.merge(poor, on=["State"]).merge(rich, on=["State"])
marr_st_income.head()
# Out:
#         State  Marriage Rate  % of households less than $10k  \
# 0     Alabama       7.577566                        7.802695
# 1      Alaska       6.315232                        5.390493
# 2     Arizona       5.422112                        5.760895
# 3    Arkansas       8.216753                        7.666248
# 4  California       5.184868                        5.342869
#
#    % of households over $200k
# 0                    5.100286
# 1                   10.209686
# 2                    7.863975
# 3                    4.599023
# 4                   14.922772

# %%
#read political party for each state dataset
state_pol_party = pd.read_csv("/Users/conniechou/Library/CloudStorage/OneDrive-Personal/Connie/Homework/GSB 521 Pierce /Cloud-Computing-Projects/project1/state-pol-party.csv",
                             header = None)
state_pol_party = state_pol_party.rename(columns={0: "State",
                                          1: "Party"})
#drop district of columbia
state_pol_party = state_pol_party.drop(state_pol_party[state_pol_party["State"] == "District of Columbia"].index)
state_pol_party.head()
# Out:
#         State       Party
# 0     Alabama  Republican
# 1      Alaska  Republican
# 2     Arizona    Democrat
# 3    Arkansas  Republican
# 4  California    Democrat

# %%
#merge with main dataset
new_merged = marr_st_income.merge(state_pol_party, on=["State"])
new_merged
# Out:
#              State  Marriage Rate  % of households less than $10k  \
# 0          Alabama       7.577566                        7.802695
# 1           Alaska       6.315232                        5.390493
# 2          Arizona       5.422112                        5.760895
# 3         Arkansas       8.216753                        7.666248
# 4       California       5.184868                        5.342869
# 5         Colorado       7.388935                        4.766406
# 6      Connecticut       5.405762                        5.216403
# 7         Delaware       4.869522                        5.182280
# 8          Florida       6.845467                        6.402690
# 9          Georgia       5.519018                        6.356331
# 10          Hawaii      12.830607                        5.426003
# 11           Idaho       7.381677                        4.417256
# 12        Illinois       4.694562                        6.391969
# 13         Indiana       5.979002                        5.678495
# 14            Iowa       5.330905                        4.959699
# 15          Kansas       5.352721                        5.715410
# 16        Kentucky       6.298407                        8.249502
# 17       Louisiana       4.377767                        9.321435
# 18           Maine       7.312823                        5.444010
# 19        Maryland       5.231845                        5.226124
# 20   Massachusetts       4.582000                        5.388363
# 21        Michigan       5.161972                        6.401684
# 22       Minnesota       4.796063                        4.221514
# 23     Mississippi       6.048207                        9.438499
# 24        Missouri       6.039700                        5.936820
# 25         Montana      11.024468                        5.166511
# 26        Nebraska       5.314988                        5.184677
# 27          Nevada      26.204273                        7.384936
# 28   New Hampshire       6.737980                        3.157965
# 29      New Jersey       5.108701                        4.861147
# 30      New Mexico       5.931347                        9.039594
# 31        New York       5.224463                        6.938461
# 32  North Carolina       6.223296                        6.401916
# 33    North Dakota       5.162927                        5.647249
# 34            Ohio       5.246427                        6.569116
# 35        Oklahoma       6.121698                        6.849177
# 36          Oregon       5.711991                        5.323166
# 37    Pennsylvania       5.416592                        5.844293
# 38    Rhode Island       5.800422                        5.844023
# 39  South Carolina       6.533987                        7.183018
# 40    South Dakota       6.266641                        4.807684
# 41       Tennessee       7.602916                        6.612081
# 42           Texas       5.773718                        6.253304
# 43            Utah       9.084550                        4.333682
# 44         Vermont       7.379525                        4.068655
# 45        Virginia       5.908052                        5.029153
# 46      Washington       5.479608                        4.807188
# 47   West Virginia       6.041081                        8.523329
# 48       Wisconsin       5.023145                        4.830537
# 49         Wyoming       7.392844                        6.038400
#
#     % of households over $200k       Party
# 0                     5.100286  Republican
# 1                    10.209686  Republican
# 2                     7.863975    Democrat
# 3                     4.599023  Republican
# 4                    14.922772    Democrat
# 5                    11.928292    Democrat
# 6                    14.656114    Democrat
# 7                     8.346897    Democrat
# 8                     7.687770  Republican
# 9                     8.221685  Republican
# 10                   13.263050    Democrat
# 11                    6.535922  Republican
# 12                    9.950232    Democrat
# 13                    5.620418  Republican
# 14                    6.174359  Republican
# 15                    6.296262    Democrat
# 16                    5.058676    Democrat
# 17                    5.567091    Democrat
# 18                    6.623430    Democrat
# 19                   15.082849    Democrat
# 20                   17.122964    Democrat
# 21                    6.673999    Democrat
# 22                    9.895273    Democrat
# 23                    3.514465  Republican
# 24                    6.367547  Republican
# 25                    6.856904  Republican
# 26                    6.593105  Republican
# 27                    7.251225  Republican
# 28                   11.333451  Republican
# 29                   16.839012    Democrat
# 30                    5.755425    Democrat
# 31                   13.036724    Democrat
# 32                    7.292284    Democrat
# 33                    6.017469  Republican
# 34                    6.437290  Republican
# 35                    4.895017  Republican
# 36                    8.984200    Democrat
# 37                    8.638292    Democrat
# 38                   10.299245    Democrat
# 39                    5.835943  Republican
# 40                    5.685833  Republican
# 41                    6.305438  Republican
# 42                    8.385553  Republican
# 43                    9.924820  Republican
# 44                    8.718070  Republican
# 45                   13.325089  Republican
# 46                   13.666878    Democrat
# 47                    4.316001  Republican
# 48                    6.502886    Democrat
# 49                    5.840676  Republican

# %%
top10=new_merged.sort_values(by="Marriage Rate", ascending = False).head(10)
top10
# Out:
#         State  Marriage Rate  % of households less than $10k  \
# 27     Nevada      26.204273                        7.384936
# 10     Hawaii      12.830607                        5.426003
# 25    Montana      11.024468                        5.166511
# 43       Utah       9.084550                        4.333682
# 3    Arkansas       8.216753                        7.666248
# 41  Tennessee       7.602916                        6.612081
# 0     Alabama       7.577566                        7.802695
# 49    Wyoming       7.392844                        6.038400
# 5    Colorado       7.388935                        4.766406
# 11      Idaho       7.381677                        4.417256
#
#     % of households over $200k       Party
# 27                    7.251225  Republican
# 10                   13.263050    Democrat
# 25                    6.856904  Republican
# 43                    9.924820  Republican
# 3                     4.599023  Republican
# 41                    6.305438  Republican
# 0                     5.100286  Republican
# 49                    5.840676  Republican
# 5                    11.928292    Democrat
# 11                    6.535922  Republican

# %%
top10['Party'].value_counts()
# Out:
# Republican    8
# Democrat      2
# Name: Party, dtype: int64

# %%
#visualize
(ggplot(new_merged, aes(x="% of households over $200k", 
                            y="% of households less than $10k", 
                            size="Marriage Rate",
                       fill="Party"))
 + geom_point()
 + theme_minimal()
+ scale_fill_manual(values = ["blue", "red"])

 # + facet_wrap("Party")
 + theme(figure_size=(10,8))
)
# Out:
# <Figure Size: (1000 x 800)>

# %%
#boxplot of party and marriage rates
(ggplot(new_merged, aes(x="Party", y="Marriage Rate", fill="Party"))
 + geom_boxplot()
 + scale_fill_manual(values = ["blue", "red"])
 + theme_minimal()
)
# Out:
# <Figure Size: (640 x 480)>

# %%
#scatter plot of <10k income and marriage rates
(ggplot(new_merged, aes(x="% of households less than $10k", y="Marriage Rate", fill="Party"))
 + geom_point(size=4)
  + scale_fill_manual(values = ["blue", "red"])

)
# Out:
# <Figure Size: (640 x 480)>

# %%
#scatter plot of >200k income and marriage rates
(ggplot(new_merged, aes(x="% of households over $200k", y="Marriage Rate", fill="Party"))
 + geom_point(size=4)
  + scale_fill_manual(values = ["blue", "red"])

)
# Out:
# <Figure Size: (640 x 480)>

# %%
new_merged.sort_values(by=["% of households less than $10k", "% of households over $200k"], ascending = [False, False])
# Out:
#              State  Marriage Rate  % of households less than $10k  \
# 23     Mississippi       6.048207                        9.438499
# 17       Louisiana       4.377767                        9.321435
# 30      New Mexico       5.931347                        9.039594
# 47   West Virginia       6.041081                        8.523329
# 16        Kentucky       6.298407                        8.249502
# 0          Alabama       7.577566                        7.802695
# 3         Arkansas       8.216753                        7.666248
# 27          Nevada      26.204273                        7.384936
# 39  South Carolina       6.533987                        7.183018
# 31        New York       5.224463                        6.938461
# 35        Oklahoma       6.121698                        6.849177
# 41       Tennessee       7.602916                        6.612081
# 34            Ohio       5.246427                        6.569116
# 8          Florida       6.845467                        6.402690
# 32  North Carolina       6.223296                        6.401916
# 21        Michigan       5.161972                        6.401684
# 12        Illinois       4.694562                        6.391969
# 9          Georgia       5.519018                        6.356331
# 42           Texas       5.773718                        6.253304
# 49         Wyoming       7.392844                        6.038400
# 24        Missouri       6.039700                        5.936820
# 37    Pennsylvania       5.416592                        5.844293
# 38    Rhode Island       5.800422                        5.844023
# 2          Arizona       5.422112                        5.760895
# 15          Kansas       5.352721                        5.715410
# 13         Indiana       5.979002                        5.678495
# 33    North Dakota       5.162927                        5.647249
# 18           Maine       7.312823                        5.444010
# 10          Hawaii      12.830607                        5.426003
# 1           Alaska       6.315232                        5.390493
# 20   Massachusetts       4.582000                        5.388363
# 4       California       5.184868                        5.342869
# 36          Oregon       5.711991                        5.323166
# 19        Maryland       5.231845                        5.226124
# 6      Connecticut       5.405762                        5.216403
# 26        Nebraska       5.314988                        5.184677
# 7         Delaware       4.869522                        5.182280
# 25         Montana      11.024468                        5.166511
# 45        Virginia       5.908052                        5.029153
# 14            Iowa       5.330905                        4.959699
# 29      New Jersey       5.108701                        4.861147
# 48       Wisconsin       5.023145                        4.830537
# 40    South Dakota       6.266641                        4.807684
# 46      Washington       5.479608                        4.807188
# 5         Colorado       7.388935                        4.766406
# 11           Idaho       7.381677                        4.417256
# 43            Utah       9.084550                        4.333682
# 22       Minnesota       4.796063                        4.221514
# 44         Vermont       7.379525                        4.068655
# 28   New Hampshire       6.737980                        3.157965
#
#     % of households over $200k       Party
# 23                    3.514465  Republican
# 17                    5.567091    Democrat
# 30                    5.755425    Democrat
# 47                    4.316001  Republican
# 16                    5.058676    Democrat
# 0                     5.100286  Republican
# 3                     4.599023  Republican
# 27                    7.251225  Republican
# 39                    5.835943  Republican
# 31                   13.036724    Democrat
# 35                    4.895017  Republican
# 41                    6.305438  Republican
# 34                    6.437290  Republican
# 8                     7.687770  Republican
# 32                    7.292284    Democrat
# 21                    6.673999    Democrat
# 12                    9.950232    Democrat
# 9                     8.221685  Republican
# 42                    8.385553  Republican
# 49                    5.840676  Republican
# 24                    6.367547  Republican
# 37                    8.638292    Democrat
# 38                   10.299245    Democrat
# 2                     7.863975    Democrat
# 15                    6.296262    Democrat
# 13                    5.620418  Republican
# 33                    6.017469  Republican
# 18                    6.623430    Democrat
# 10                   13.263050    Democrat
# 1                    10.209686  Republican
# 20                   17.122964    Democrat
# 4                    14.922772    Democrat
# 36                    8.984200    Democrat
# 19                   15.082849    Democrat
# 6                    14.656114    Democrat
# 26                    6.593105  Republican
# 7                     8.346897    Democrat
# 25                    6.856904  Republican
# 45                   13.325089  Republican
# 14                    6.174359  Republican
# 29                   16.839012    Democrat
# 48                    6.502886    Democrat
# 40                    5.685833  Republican
# 46                   13.666878    Democrat
# 5                    11.928292    Democrat
# 11                    6.535922  Republican
# 43                    9.924820  Republican
# 22                    9.895273    Democrat
# 44                    8.718070  Republican
# 28                   11.333451  Republican

# %%
#drop nevada and hawaii
no_NV_HI = new_merged[(new_merged["State"] != "Nevada") & (new_merged["State"] != "Hawaii")]
no_NV_HI
# Out:
#              State  Marriage Rate  % of households less than $10k  \
# 0          Alabama       7.577566                        7.802695
# 1           Alaska       6.315232                        5.390493
# 2          Arizona       5.422112                        5.760895
# 3         Arkansas       8.216753                        7.666248
# 4       California       5.184868                        5.342869
# 5         Colorado       7.388935                        4.766406
# 6      Connecticut       5.405762                        5.216403
# 7         Delaware       4.869522                        5.182280
# 8          Florida       6.845467                        6.402690
# 9          Georgia       5.519018                        6.356331
# 11           Idaho       7.381677                        4.417256
# 12        Illinois       4.694562                        6.391969
# 13         Indiana       5.979002                        5.678495
# 14            Iowa       5.330905                        4.959699
# 15          Kansas       5.352721                        5.715410
# 16        Kentucky       6.298407                        8.249502
# 17       Louisiana       4.377767                        9.321435
# 18           Maine       7.312823                        5.444010
# 19        Maryland       5.231845                        5.226124
# 20   Massachusetts       4.582000                        5.388363
# 21        Michigan       5.161972                        6.401684
# 22       Minnesota       4.796063                        4.221514
# 23     Mississippi       6.048207                        9.438499
# 24        Missouri       6.039700                        5.936820
# 25         Montana      11.024468                        5.166511
# 26        Nebraska       5.314988                        5.184677
# 28   New Hampshire       6.737980                        3.157965
# 29      New Jersey       5.108701                        4.861147
# 30      New Mexico       5.931347                        9.039594
# 31        New York       5.224463                        6.938461
# 32  North Carolina       6.223296                        6.401916
# 33    North Dakota       5.162927                        5.647249
# 34            Ohio       5.246427                        6.569116
# 35        Oklahoma       6.121698                        6.849177
# 36          Oregon       5.711991                        5.323166
# 37    Pennsylvania       5.416592                        5.844293
# 38    Rhode Island       5.800422                        5.844023
# 39  South Carolina       6.533987                        7.183018
# 40    South Dakota       6.266641                        4.807684
# 41       Tennessee       7.602916                        6.612081
# 42           Texas       5.773718                        6.253304
# 43            Utah       9.084550                        4.333682
# 44         Vermont       7.379525                        4.068655
# 45        Virginia       5.908052                        5.029153
# 46      Washington       5.479608                        4.807188
# 47   West Virginia       6.041081                        8.523329
# 48       Wisconsin       5.023145                        4.830537
# 49         Wyoming       7.392844                        6.038400
#
#     % of households over $200k       Party
# 0                     5.100286  Republican
# 1                    10.209686  Republican
# 2                     7.863975    Democrat
# 3                     4.599023  Republican
# 4                    14.922772    Democrat
# 5                    11.928292    Democrat
# 6                    14.656114    Democrat
# 7                     8.346897    Democrat
# 8                     7.687770  Republican
# 9                     8.221685  Republican
# 11                    6.535922  Republican
# 12                    9.950232    Democrat
# 13                    5.620418  Republican
# 14                    6.174359  Republican
# 15                    6.296262    Democrat
# 16                    5.058676    Democrat
# 17                    5.567091    Democrat
# 18                    6.623430    Democrat
# 19                   15.082849    Democrat
# 20                   17.122964    Democrat
# 21                    6.673999    Democrat
# 22                    9.895273    Democrat
# 23                    3.514465  Republican
# 24                    6.367547  Republican
# 25                    6.856904  Republican
# 26                    6.593105  Republican
# 28                   11.333451  Republican
# 29                   16.839012    Democrat
# 30                    5.755425    Democrat
# 31                   13.036724    Democrat
# 32                    7.292284    Democrat
# 33                    6.017469  Republican
# 34                    6.437290  Republican
# 35                    4.895017  Republican
# 36                    8.984200    Democrat
# 37                    8.638292    Democrat
# 38                   10.299245    Democrat
# 39                    5.835943  Republican
# 40                    5.685833  Republican
# 41                    6.305438  Republican
# 42                    8.385553  Republican
# 43                    9.924820  Republican
# 44                    8.718070  Republican
# 45                   13.325089  Republican
# 46                   13.666878    Democrat
# 47                    4.316001  Republican
# 48                    6.502886    Democrat
# 49                    5.840676  Republican

# %%
#boxplot of party and marriage rates
(ggplot(no_NV_HI, aes(x="Party", y="Marriage Rate", fill="Party"))
 + geom_boxplot()
 + scale_fill_manual(values = ["blue", "red"])
 + theme_minimal()
)
# Out:
# <Figure Size: (640 x 480)>
